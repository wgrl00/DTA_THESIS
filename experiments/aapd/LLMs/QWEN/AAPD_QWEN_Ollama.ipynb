# %%
# !sudo apt-get install -y zstd pciutils lshw
# !curl -fsSL https://ollama.com/install.sh | sh

import subprocess, time
subprocess.Popen(["ollama", "serve"])
time.sleep(8)

# !ollama pull "qwen2.5:7b"
print("Ollama ready.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pciutils is already the newest version (1:3.7.0-6).
# zstd is already the newest version (1.4.8+dfsg-3build1).
# lshw is already the newest version (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 53 not upgraded.
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
#
# Ollama ready.

# %%
# !pip install -q requests

# %%
import zipfile
import json
import pandas as pd
import numpy as np
import joblib
from datetime import datetime
import os
import time
import random
import requests
from google.colab import userdata
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score
import re

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %%
#checking whether ollama is running
resp = requests.get("http://localhost:11434/api/tags")
print("Ollama status:", resp.status_code)
models = [m["name"] for m in resp.json().get("models", [])]
print("Available models:", models)
# Out:
# Ollama status: 200
# Available models: ['qwen2.5:7b', 'qwen3.5:9b']

# %%
OLLAMA_MODEL = "qwen2.5:7b"
OLLAMA_URL = "http://localhost:11434/api/chat"

# %%
LABEL_DESC = "aapd_label_descriptions_prompt_friendly.json"
VAL_GREEDY_INPUT = "aapd_validation_greedy_llm_input_data.jsonl"
VAL_TOPK_INPUT = "aapd_validation_top_k_llm_input_data.jsonl"
VAL_GOLD_LABELS = "aapd_validation_gold_labels.json"
N_RETRIEVED = 5

# %%
from google.colab import drive
drive.mount("/content/drive")
OUTPUT_DIR = "/content/drive/MyDrive/thesis_results/AAPD_QWEN_OLLAMA_outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

GREEDY_VAL_OUTPUT = f"{OUTPUT_DIR}/AAPD_qwen_OLLAMA_val_greedy_predictions.jsonl"
TOPK_VAL_OUTPUT = f"{OUTPUT_DIR}/AAPD_qwen_OLLAMA_val_topk_predictions.jsonl"
LABELS_ONLY_VAL_OUTPUT = f"{OUTPUT_DIR}/AAPD_qwen_OLLAMA_val_labels_only_predictions.jsonl"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with zipfile.ZipFile("aapd.zip") as z:
    with z.open("aapd.json") as f:
        aapd = json.load(f)

# %%
aapd_df_val = pd.DataFrame(aapd["data"]["val"])
aapd_df_test = pd.DataFrame(aapd["data"]["test"])

print("Validation shape:", aapd_df_val.shape)
print("Test shape:", aapd_df_test.shape)
#ok
# Out:
# Validation shape: (1000, 3)
# Test shape: (1000, 3)

# %%
#loading retrieval results

#helper function
def load_jsonl(path):
    rows = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                rows.append(json.loads(line))
    return rows

#validation only for now
val_greedy_items = load_jsonl(VAL_GREEDY_INPUT)
val_topk_items = load_jsonl(VAL_TOPK_INPUT)

print(val_greedy_items[0].keys())
print(val_greedy_items[0])
# Out:
# dict_keys(['query_id', 'target_text', 'retrieved_examples'])
# {'query_id': 0, 'target_text': 'linked open datasets about scholarly publications enable the development and integration of sophisticated end user services however , richer datasets are still needed the first goal of this challenge was to investigate novel approaches to obtain such semantic data in particular , we were seeking methods and tools to extract information from scholarly publications , to publish it as lod , and to use queries over this lod to assess quality this year we focused on the quality of workshop proceedings , and of journal articles w r t their citation network a third , open task , asked to showcase how such semantic data could be exploited and how semantic web technologies could help in this emerging context\n', 'retrieved_examples': [{'train_index': 26088, 'labels': ['Databases', 'Computational Engineering, Finance, and Science', 'Information Retrieval'], 'text': 'the linked clinical trials \\( linkedct \\) project aims at publishing the first open semantic web data source for clinical trials data the database exposed by linkedct is generated by \\( 1 \\) transforming existing data sources of clinical trials into rdf , and \\( 2 \\) discovering semantic links between the records in the trials data and several other data sources in this paper , we discuss several challenges involved in these two steps and present the methodology used in linkedct to overcome these challenges our approach for semantic link discovery involves using state of the art approximate string matching techniques combined with ontology based semantic matching of the records , all performed in a declarative and easy to use framework we present an evaluation of the performance of our proposed techniques in several link discovery scenarios in linkedct\n'}, {'train_index': 22499, 'labels': ['Digital Libraries', 'Artificial Intelligence', 'Human-Computer Interaction', 'Information Retrieval'], 'text': 'this paper is concerned with tracking and interpreting scholarly documents in distributed research communities we argue that current approaches to document description , and current technological infrastructures particularly over the world wide web , provide poor support for these tasks we describe the design of a digital library server which will enable authors to submit a summary of the contributions they claim their documents makes , and its relations to the literature we describe a knowledge based web environment to support the emergence of such a community constructed semantic hypertext , and the services it could provide to assist the interpretation of an idea or document in the context of its literature the discussion considers in detail how the approach addresses usability issues associated with knowledge structuring environments\n'}, {'train_index': 35625, 'labels': ['Networking and Internet Architecture', 'Information Retrieval'], 'text': 'the aim of this paper is to introduce the idea of the semantic web to the complexity community and set a basic ground for a project resulting in creation of internet based semantic network of complexity related information providers implementation of the semantic web technology would be of mutual benefit to both the participants and users and will confirm self referencing power of the community to apply the products of its own research to itself we first explain the logic of the transition and discuss important notions associated with the semantic web technology we then present a brief outline of the project milestones\n'}, {'train_index': 49970, 'labels': ['Digital Libraries', 'Mathematical Software'], 'text': "the term 'linked data' refers to a set of best practices for publishing and connecting structured data on the web linked data make the semantic web work practically , which means that information can be retrieved without complicated lookup mechanisms , that a lightweight semantics enables scalable reasoning , and that the decentral nature of the web is respected openmath content dictiona ...

# %%
#for evaluating the validation results
with open(VAL_GOLD_LABELS, "r", encoding="utf-8") as f:
    val_gold_labels = json.load(f)

# %%
#reusing the same mlb I created for SVC
mlb = joblib.load("mlb.joblib")
ALL_LABELS = list(mlb.classes_)
print("Number of labels:", len(ALL_LABELS))

#label block for inserting into prompt
with open(LABEL_DESC, "r", encoding="utf-8") as f:
    label_descriptions = json.load(f)

#check that descriptions and mlb labels match
desc_labels = set(label_descriptions.keys())
mlb_labels = set(ALL_LABELS)
assert mlb_labels == desc_labels, "Mismatch!"
# Out:
# Number of labels: 54

# %%
OLLAMA_OPTIONS = {
    "temperature": 0,
    "num_predict": 192,
    "seed": SEED}

# %%
def label_block(label_descriptions, labels):
    lines = []
    for label in labels:
        desc = label_descriptions[label]
        lines.append(f" - {label}: {desc}")
    return "\n".join(lines)

LABEL_BLOCK = label_block(label_descriptions, ALL_LABELS)

print(LABEL_BLOCK)
#will be provided in-context
print("Number of labels:", len(ALL_LABELS)) #ok
print(f"Number of words:{len(LABEL_BLOCK.split())}")
# Out:
#  - Adaptation and Self-Organizing Systems: Focuses on systems that adapt and self-organize, including statistical physics and stochastic processes. Does not cover general machine learning topics outside of self-organization. Relevant to physics applications in complex systems.
#  - Applications: Covers the application of statistical methods across various fields such as biology, engineering, and social sciences. Does not include theoretical statistics or methodology. Emphasizes practical implementations and case studies.
#  - Artificial Intelligence: Encompasses all AI topics except for Vision, Robotics, Machine Learning, Multiagent Systems, and Computation and Language. Does not include practical applications of AI methods, which may fall under Applications. Focuses on theoretical aspects like knowledge representation and planning.
#  - Combinatorics: Covers discrete mathematics topics such as graph theory, enumeration, and combinatorial optimization. Does not include continuous mathematics or general mathematical theory. Focuses on counting and arrangement problems.
#  - Computation and Language: Focuses on natural language processing and computational linguistics. Does not cover programming languages or formal systems unrelated to natural language. Emphasizes algorithms and models for language understanding.
#  - Computational Complexity: Covers models of computation, complexity classes, and trade-offs in computational resources. Does not include practical algorithm design, which is better suited for Data Structures and Algorithms. Focuses on theoretical limits of computation.
#  - Computational Engineering, Finance, and Science: Covers interdisciplinary applications of computer science in modeling complex systems in engineering, finance, and science. Does not include theoretical computer science topics. Emphasizes computational simulations and high-performance computing.
#  - Computational Geometry: Focuses on geometric algorithms and their applications in computer science. Does not cover general geometry or non-computational aspects. Emphasizes spatial data structures and geometric modeling.
#  - Computational Linguistics: Covers the computational aspects of linguistic theory and natural language processing. Does not include general linguistics or non-computational studies. Focuses on algorithms and models for language analysis.
#  - Computer Science and Game Theory: Covers the intersection of computer science and game theory, including mechanism design and learning in games. Does not include general game theory applications outside of computing. Emphasizes theoretical foundations and computational strategies.
#  - Computer Vision and Pattern Recognition: Focuses on image processing, computer vision, and pattern recognition techniques. Does not cover general AI or machine learning topics unrelated to vision. Emphasizes algorithms for visual data analysis.
#  - Computers and Society: Covers the societal impacts of computing, including ethics and public policy. Does not include technical aspects of computer science. Emphasizes the relationship between technology and social issues.
#  - Cryptography and Security: Covers all aspects of cryptography, including authentication and encryption methods. Does not include general security practices outside of cryptographic techniques. Emphasizes theoretical and practical aspects of secure communication.
#  - Data Analysis, Statistics and Probability: Focuses on methods and tools for data analysis in physics, including statistical methodologies. Does not cover general statistical theory or applications outside of physics. Emphasizes practical data processing techniques.
#  - Data Structures and Algorithms: Covers the design and analysis of data structures and algorithms. Does not include general computational theory or complexity analysis. Emphasizes practical algorithm implementation and efficiency.
#  - Databases: Focuses on database management, data mining, and data processing techniques. Does not cover general data analysis or theoretical database design. Emphasizes practical applications in data storage and retrieval.
#  - Digital Libraries: Covers the design and implementation of digital libraries and document creation. Does not include general information retrieval topics. Emphasizes the organization and accessibility of digital content.
#  - Discrete Mathematics: Covers combinatorial structures, graph theory, and discrete probability applications. Does not include continuous mathematics or general mathematical theory. Emphasizes finite structures and their properties.
#  - Disordered Systems and Neural Networks: Focuses on properties of disordered systems and neural network models. Does not cover general physics or non-neural network topics. Emphasizes the interplay between disorder and neural computation.
#  - Distributed, Parallel, and Cluster Computing: Covers distributed algorithms, fault tolerance, and parallel computing techniques. Does not include general computing theory or single-threaded algorithms. Emphasizes scalability and performance in computing systems.
#  - Formal Languages and Automata Theory: Covers automata theory, formal languages, and grammars. Does not include computational complexity or logic topics. Emphasizes theoretical foundations of computation and language structure.
#  - Human-Computer Interaction: Focuses on user interface design, human factors, and collaborative computing. Does not include general software engineering topics. Emphasizes the interaction between users and computer systems.
#  - Information Retrieval: Covers techniques for indexing, retrieval, and content analysis. Does not include general data processing or database management topics. Emphasizes efficient access to information and data.
#  - Information Theory (Computer Science): Covers theoretical aspects of information theory and coding in computer science. Does not include mathematical information theory topics. Emphasizes applications in data compression and communication.
#  - Information Theory (Mathematics): Covers theoretical aspects of information theory and coding in mathematics. Does not include computer science applications. Emphasizes mathematical foundations and proofs.
#  - Logic: Covers formal logic, set theory, and mathematical foundations. Does not include computational logic or applications in computer science. Emphasizes theoretical aspects of logical systems.
#  - Logic in Computer Science: Covers logic applications in computer science, including program verification and modal logic. Does not include general mathematical logic. Emphasizes the role of logic in computational systems.
#  - Machine Learning (Computer Science): Covers all aspects of machine learning research, including supervised and unsupervised learning. Does not include statistical theory or applications outside of computer science. Emphasizes practical implementations and methodologies.
#  - Machine Learning (Statistics): Focuses on machine learning with a statistical grounding, including theoretical aspects. Does not cover general machine learning applications in computer science. Emphasizes statistical methods and inference.
#  - Mathematical Software: Covers software tools for mathematical computation and analysis. Does not include general programming or software engineering topics. Emphasizes applications in mathematical problem-solving.
#  - Methodology: Covers statistical design, model selection, and experimental methods. Does not include general statistical theory or applications outside of methodology. Emphasizes practical approaches to statistical analysis.
#  - Multiagent Systems: Covers systems involving multiple intelligent agents and their interactions. Does not include general AI topics unrelated to multiagent systems. Emphasizes coordination and collaboration among agents.
#  - Multimedia: Covers multimedia information systems and their applications. Does not include general computer science topics. Emphasizes the integration of various media types in computing.
#  - Networking and Internet Architecture: Covers computer communication networks, protocols, and architecture. Does not include general computing topics unrelated to networking. Emphasizes the design and performance of network systems.
#  - Neural and Evolutionary Computing: Covers neural networks and evolutionary algorithms. Does not include general machine learning topics. Emphasizes biologically inspired computation and adaptive systems.
#  - Neurons and Cognition: Focuses on neuronal dynamics and cognitive processes. Does not cover general neuroscience or non-cognitive topics. Emphasizes the relationship between neural activity and behavior.
#  - Number Theory: Covers prime numbers, diophantine equations, and analytic number theory. Does not include general algebra or continuous mathematics. Emphasizes properties and relationships of integers.
#  - Numerical Analysis (Computer Science): Covers numerical methods and algorithms in computer science. Does not include general mathematical analysis topics. Emphasizes computational techniques for solving numerical problems.
#  - Numerical Analysis (Mathematics): Focuses on numerical algorithms for mathematical problems. Does not include general computational topics. Emphasizes theoretical aspects of numerical methods.
#  - Optimization and Control: Covers operations research, control theory, and optimization methods. Does not include general mathematical theory unrelated to optimization. Emphasizes practical applications in decision-making.
#  - Performance: Covers performance measurement and evaluation in computing systems. Does not include general algorithm design or theoretical topics. Emphasizes practical metrics and benchmarks.
#  - Physics and Society: Covers the intersection of physics and societal issues, including social networks. Does not include general physics topics unrelated to society. Emphasizes quantitative analysis of social phenomena.
#  - Probability: Covers theory and applications of probability and stochastic processes. Does not include general statistics or non-probabilistic topics. Emphasizes mathematical foundations and applications in various fields.
#  - Programming Languages: Covers programming language design, semantics, and features. Does not include general software engineering topics. Emphasizes theoretical and practical aspects of programming languages.
#  - Quantitative Methods: Covers experimental and statistical methods in biology. Does not include general quantitative analysis unrelated to biology. Emphasizes practical applications in biological research.
#  - Quantum Physics: Covers theoretical and experimental aspects of quantum mechanics. Does not include general physics topics outside of quantum theory. Emphasizes foundational principles and applications.
#  - Robotics: Covers robotic systems and their applications. Does not include general AI or machine learning topics. Emphasizes practical implementations and robotic technologies.
#  - Social and Information Networks: Covers design and analysis of social and information networks. Does not include general networking topics unrelated to social systems. Emphasizes applications in communication and data analysis.
#  - Software Engineering: Covers software design, testing, and development methodologies. Does not include general programming topics unrelated to software engineering. Emphasizes practical tools and techniques for software development.
#  - Statistical Mechanics: Covers phase transitions and thermodynamic phenomena. Does not include general physics topics unrelated to statistical mechanics. Emphasizes theoretical and experimental studies in statistical physics.
#  - Statistics Theory (Mathematics): Covers theoretical aspects of statistics, including inference and regression. Does not include applied statistics or methodology topics. Emphasizes mathematical foundations of statistical theory.
#  - Statistics Theory (Statistics): Covers theoretical statistics, including Bayesian inference and decision theory. Does not include applied statistics or general statistical methods. Emphasizes theoretical frameworks and models.
#  - Symbolic Computation: Covers symbolic and algebraic manipulation techniques. Does not include numerical methods or general programming topics. Emphasizes theoretical aspects of symbolic computation.
#  - Systems and Control (Computer Science): Covers automatic control systems and their analysis. Does not include general computer science topics unrelated to control. Emphasizes methods for system design and optimization.
# Number of labels: 54
# Number of words:1566

# %%
label_schema = {
    "type": "object",
    "properties": {
        "predicted_labels": {
            "type": "array",
            "items": {
                "type": "string",
                "enum": ALL_LABELS},
        }
    },
    "required": ["predicted_labels"],
    "additionalProperties": False}

# %%
def warmup_ollama():
    """Send a short request to load the model into GPU memory."""
    resp = requests.post(OLLAMA_URL, json={
        "model": OLLAMA_MODEL,
        "messages": [{"role": "user", "content": "Hi"}],
        "stream": False,
        "options": {"num_predict": 5}
    })
    print("Ollama warmup done:", resp.status_code)

# %%
warmup_ollama()
# Out:
# Ollama warmup done: 200

# %%
#check
print("Validation df length:", len(aapd_df_val))
print("Greedy items length:", len(val_greedy_items))
print("Top-k items length:", len(val_topk_items))
#checking whether the first target text is the same as val
print(val_greedy_items[0]["target_text"][:200])
print(aapd_df_val.iloc[0]["text"][:200])
# Out:
# Validation df length: 1000
# Greedy items length: 1000
# Top-k items length: 1000
# linked open datasets about scholarly publications enable the development and integration of sophisticated end user services however , richer datasets are still needed the first goal of this challenge
# linked open datasets about scholarly publications enable the development and integration of sophisticated end user services however , richer datasets are still needed the first goal of this challenge

# %%
#since the AAPD abstracts are preprocessed in a way that punctuation appears after spaces (making them separate tokens),
#which is useful for SVC/transformers but not necessarily for LLMs
#I will send the text as more natural looking
def detokenize(text):
    text = str(text).strip()
    text = re.sub(r"\s+([,.;:!?])", r"\1", text)
    text = re.sub(r"\(\s+", "(", text)
    text = re.sub(r"\s+\)", ")", text)
    text = re.sub(r"\s+", " ", text)
    return text

#formatting the retrieved examples for in-prompt placement
def format_retrieved_examples(retrieved_examples, n=N_RETRIEVED):
    example_blocks = []
    for i, ex in enumerate(retrieved_examples[:n], start=1):
        text = detokenize(ex["text"])
        labels = ex["labels"]

        example_blocks.append(
            f"Example {i}\n"
            f"Abstract:\n{text}\n"
            f"Labels:\n{json.dumps(labels, ensure_ascii=False)}")
    return "\n\n".join(example_blocks)

# %% [markdown]
# ##Building prompts

# %%
def build_prompt_with_examples(target_text, retrieved_examples):
    target_text = detokenize(target_text)
    examples_block = format_retrieved_examples(retrieved_examples)

    system_message = (
        "You are an expert in multi-label topic classification. "
        "Use only the allowed label names and return only the required JSON object.")

    user_message = f"""
You are performing multi-label topic classification for academic abstracts.
Your task is to assign the most appropriate topic labels to the target abstract.
Use only labels from the allowed label set below.

Allowed labels and descriptions:
{LABEL_BLOCK}

Below are retrieved labelled demonstrations. They show examples of abstracts and their assigned labels.
{examples_block}

Now classify the target abstract.

Target abstract:
{target_text}

Return exactly one JSON object in this format:
{{"predicted_labels": ["label1", "label2"]}}

Rules:
- Use only exact label names from the allowed label set.
- Select only labels that are directly supported by the main topic of the target abstract.
- Use the retrieved demonstrations as guidance, but do not copy their labels unless the target abstract itself supports them.
- Return only the JSON object, with no explanation or extra text.

""".strip()

    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message}]

# %%
def build_prompt_labels_only(target_text):
    target_text = detokenize(target_text)

    system_message = (
        "You are an expert in multi-label topic classification. "
        "Use only the allowed label names and return only the required JSON object.")

    user_message = f"""
You are performing multi-label topic classification for academic abstracts.
Your task is to assign the most appropriate topic labels to the target abstract.
Use only labels from the allowed label set below.

Allowed labels and descriptions:
{LABEL_BLOCK}

Now classify the target abstract.

Target abstract:
{target_text}

Return exactly one JSON object in this format:
{{"predicted_labels": ["label1", "label2"]}}

Rules:
- Use only exact label names from the allowed label set.
- Select only labels that are directly supported by the target abstract.
- Return only the JSON object, with no explanation or extra text.

""".strip()

    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message}]

# %%
def build_greedy_messages(item):
    return build_prompt_with_examples(target_text=item["target_text"], retrieved_examples=item["retrieved_examples"])


def build_topk_messages(item):
    return build_prompt_with_examples(target_text=item["target_text"], retrieved_examples=item["retrieved_examples"])


def build_labels_only_messages(item):
    return build_prompt_labels_only(target_text=item["target_text"])

# %%
def generate_ollama_response(messages):
    total_start = time.time()

    resp = requests.post(OLLAMA_URL, json={
        "model": OLLAMA_MODEL,
        "messages": messages,
        "format": label_schema,
        "stream": False,
        "options": OLLAMA_OPTIONS
    })
    resp.raise_for_status()
    data = resp.json()

    total_runtime = time.time() - total_start
    raw_output = data["message"]["content"].strip()

    # Ollama returns token counts and timing natively
    input_tokens = data.get("prompt_eval_count")
    output_tokens = data.get("eval_count")
    # eval_duration is in nanoseconds
    eval_ns = data.get("eval_duration", 0)
    generation_runtime = eval_ns / 1e9

    return {
        "response": raw_output,
        "generation_runtime_seconds": generation_runtime,
        "total_sample_runtime_seconds": total_runtime,
        "input_tokens": input_tokens,
        "output_tokens": output_tokens
    }

# %%
def parse_schema_output(raw_output):
    raw_output = str(raw_output).strip()
    parsed = json.loads(raw_output)

    labels = parsed["predicted_labels"]

    if not isinstance(labels, list):
        raise ValueError(f"predicted_labels is not a list: {raw_output}")

    invalid_labels = [
        label for label in labels
        if label not in ALL_LABELS
    ]

    if invalid_labels:
        raise ValueError(f"Invalid labels: {invalid_labels}")

    valid_labels = []
    for label in labels:
        if label not in valid_labels:
            valid_labels.append(label)

    return {
        "predicted_labels": valid_labels,
        "raw_output": raw_output}

# %%
def get_done_query_ids(output_path):
    done = set()

    if not os.path.exists(output_path):
        return done

    with open(output_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                try:
                    row = json.loads(line)
                    if row.get("status") == "ok":
                        done.add(row["query_id"])
                except Exception:
                    pass
    return done

# %%
def run_ollama_validation_checkpointed(
    items,
    output_path,
    strategy_name,
    build_messages_fn,
    gold_labels_dict,
    max_items=None):
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    if max_items is not None:
        items = items[:max_items]

    done_query_ids = get_done_query_ids(output_path)

    remaining_items = [
        item for item in items
        if item["query_id"] not in done_query_ids]

    print(f"Already completed: {len(done_query_ids)}")
    print(f"Remaining to run: {len(remaining_items)}")

    experiment_start = time.time()

    for item in remaining_items:
        query_id = item["query_id"]
        sample_start = time.time()

        try:
            messages = build_messages_fn(item)

            generation = generate_ollama_response(messages)
            parsed = parse_schema_output(generation["response"])

            row = {
                "status": "ok",
                "strategy": strategy_name,
                "query_id": query_id,
                "gold_labels": gold_labels_dict[str(query_id)],
                "predicted_labels": parsed["predicted_labels"],
                "raw_output": parsed["raw_output"],
                "input_tokens": generation["input_tokens"],
                "output_tokens": generation["output_tokens"],
                "generation_runtime_seconds": generation["generation_runtime_seconds"],
                "total_sample_runtime_seconds": generation["total_sample_runtime_seconds"],
                "wall_time_seconds": time.time() - sample_start,
                "timestamp": datetime.now().isoformat()}

        except Exception as e:
            row = {
                "status": "error",
                "strategy": strategy_name,
                "query_id": query_id,
                "error": repr(e),
                "wall_time_seconds": time.time() - sample_start,
                "timestamp": datetime.now().isoformat()}

        with open(output_path, "a", encoding="utf-8") as f:
            f.write(json.dumps(row, ensure_ascii=False) + "\n")
            f.flush()
            os.fsync(f.fileno())

    print(f"Finished. Total wall time: {(time.time() - experiment_start) / 60:.2f} minutes")

# %%
def load_prediction_jsonl(path):
    rows = []

    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                row = json.loads(line)
                if row.get("status") == "ok":
                    rows.append(row)

    return rows

def load_prediction_jsonl_all(path):
    rows = []

    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                rows.append(json.loads(line))

    return rows


def evaluate_prediction_file(path, mlb=mlb, require_no_errors=True):
    all_rows = load_prediction_jsonl_all(path)

    ok_rows = [row for row in all_rows if row.get("status") == "ok"]
    error_rows = [row for row in all_rows if row.get("status") == "error"]

    if require_no_errors and len(error_rows) > 0:
        raise ValueError(
            f"{path} contains {len(error_rows)} error rows. ")

    y_true_labels = [row["gold_labels"] for row in ok_rows]
    y_pred_labels = [row["predicted_labels"] for row in ok_rows]

    y_true = mlb.transform(y_true_labels)
    y_pred = mlb.transform(y_pred_labels)

    return {
        "path": path,
        "n_total_rows": len(all_rows),
        "n_examples": len(ok_rows),
        "n_error_rows": len(error_rows),
        "micro_f1": f1_score(y_true, y_pred, average="micro", zero_division=0),
        "macro_f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
        "avg_predicted_labels": np.mean([len(row["predicted_labels"]) for row in ok_rows]),
        "avg_gold_labels": np.mean([len(row["gold_labels"]) for row in ok_rows]),
        "avg_input_tokens": np.mean([row["input_tokens"] for row in ok_rows]),
        "avg_output_tokens": np.mean([row["output_tokens"] for row in ok_rows]),
        "avg_runtime_seconds": np.mean([row["wall_time_seconds"] for row in ok_rows])
    }

# %% [markdown]
# ##Full validation run

# %%
run_ollama_validation_checkpointed(
    items=val_greedy_items,
    output_path=GREEDY_VAL_OUTPUT,
    strategy_name="greedy_5_examples_label_descriptions",
    build_messages_fn=build_greedy_messages,
    gold_labels_dict=val_gold_labels)
# Out:
# Already completed: 0
# Remaining to run: 1000
# Finished. Total wall time: 44.41 minutes

# %%
run_ollama_validation_checkpointed(
    items=val_topk_items,
    output_path=TOPK_VAL_OUTPUT,
    strategy_name="topk_5_examples_label_descriptions",
    build_messages_fn=build_topk_messages,
    gold_labels_dict=val_gold_labels)
# Out:
# Already completed: 0
# Remaining to run: 1000
# Finished. Total wall time: 43.41 minutes

# %%
run_ollama_validation_checkpointed(
    items=val_greedy_items,
    output_path=LABELS_ONLY_VAL_OUTPUT,
    strategy_name="labels_only",
    build_messages_fn=build_labels_only_messages,
    gold_labels_dict=val_gold_labels)
# Out:
# Already completed: 0
# Remaining to run: 1000
# Finished. Total wall time: 24.08 minutes

# %%
results = pd.DataFrame([
    evaluate_prediction_file(GREEDY_VAL_OUTPUT),
    evaluate_prediction_file(TOPK_VAL_OUTPUT),
    evaluate_prediction_file(LABELS_ONLY_VAL_OUTPUT)])

results_path = f"{OUTPUT_DIR}/AAPD_qwen_validation_strategy_results_comparison.csv"
results.to_csv(results_path, index=False)

results
#topk + label descriptions performs best
# Out:
#                                                 path  n_total_rows  \
# 0  /content/drive/MyDrive/thesis_results/AAPD_QWE...          1000
# 1  /content/drive/MyDrive/thesis_results/AAPD_QWE...          1000
# 2  /content/drive/MyDrive/thesis_results/AAPD_QWE...          1000
#
#    n_examples  n_error_rows  micro_f1  macro_f1  avg_predicted_labels  \
# 0        1000             0  0.661212  0.512695                 2.122
# 1        1000             0  0.700356  0.537481                 2.092
# 2        1000             0  0.346840  0.280281                 1.919
#
#    avg_gold_labels  avg_input_tokens  avg_output_tokens  avg_runtime_seconds
# 0              2.4          3484.865             18.887             2.659847
# 1              2.4          3456.344             18.728             2.599380
# 2              2.4          2371.403             17.954             1.440079

# %% [markdown]
# #**Final run on test set**

# %%
TEST_TOPK_INPUT = "aapd_test_top_k_llm_input_data.jsonl"
TOPK_TEST_OUTPUT = f"{OUTPUT_DIR}/AAPD_qwen_OLLAMA_test_topk_predictions.jsonl"
TEST_GOLD_LABELS = "aapd_test_gold_labels.json"

# %%
test_topk_items = load_jsonl(TEST_TOPK_INPUT)

with open(TEST_GOLD_LABELS, "r", encoding="utf-8") as f:
    test_gold_labels = json.load(f)

print("Test top-k items:", len(test_topk_items))
print("Test gold labels:", len(test_gold_labels))
# Out:
# Test top-k items: 1000
# Test gold labels: 1000

# %%
run_ollama_validation_checkpointed(
    items=test_topk_items,
    output_path=TOPK_TEST_OUTPUT,
    strategy_name="topk_5_examples_label_descriptions_ollama_schema",
    build_messages_fn=build_topk_messages,
    gold_labels_dict=test_gold_labels,
    max_items=None)
# Out:
# Already completed: 0
# Remaining to run: 1000
# Finished. Total wall time: 43.89 minutes

# %%
test_results = evaluate_prediction_file(TOPK_TEST_OUTPUT)
pd.DataFrame([test_results])
# Out:
#                                                 path  n_total_rows  \
# 0  /content/drive/MyDrive/thesis_results/AAPD_QWE...          1000
#
#    n_examples  n_error_rows  micro_f1  macro_f1  avg_predicted_labels  \
# 0        1000             0  0.672128  0.532827                 2.096
#
#    avg_gold_labels  avg_input_tokens  avg_output_tokens  avg_runtime_seconds
# 0            2.421          3463.374             18.761             2.628696

# %%
all_rows = load_prediction_jsonl_all(TOPK_TEST_OUTPUT)

ok_rows = [row for row in all_rows if row.get("status") == "ok"]
error_rows = [row for row in all_rows if row.get("status") == "error"]

if len(error_rows) > 0:
    raise ValueError(f"{TOPK_TEST_OUTPUT} contains {len(error_rows)} error rows.")

llm_y_test_true_labels = [row["gold_labels"] for row in ok_rows]
llm_y_test_pred_labels = [row["predicted_labels"] for row in ok_rows]

llm_y_test = mlb.transform(llm_y_test_true_labels)
llm_y_test_pred = mlb.transform(llm_y_test_pred_labels)

report_dict = classification_report(llm_y_test, llm_y_test_pred, target_names=mlb.classes_, zero_division=0, output_dict=True)

report_df = pd.DataFrame(report_dict).T
report_df.to_csv(f"{OUTPUT_DIR}/AAPD_Qwen_Ollama_topk_classification_report.csv")

report_df
# Out:
#                                                  precision    recall  \
# Adaptation and Self-Organizing Systems            0.157895  0.375000
# Applications                                      0.125000  0.071429
# Artificial Intelligence                           0.659341  0.540541
# Combinatorics                                     0.629032  0.650000
# Computation and Language                          0.820000  0.803922
# Computational Complexity                          0.474576  0.636364
# Computational Engineering, Finance, and Science   0.333333  0.375000
# Computational Geometry                            0.590909  0.590909
# Computational Linguistics                         0.833333  0.666667
# Computer Science and Game Theory                  0.800000  0.689655
# Computer Vision and Pattern Recognition           0.875000  0.813953
# Computers and Society                             0.575758  0.487179
# Cryptography and Security                         0.875000  0.857143
# Data Analysis, Statistics and Probability         0.080000  0.222222
# Data Structures and Algorithms                    0.522222  0.602564
# Databases                                         0.647059  0.458333
# Digital Libraries                                 0.875000  0.538462
# Discrete Mathematics                              0.697674  0.441176
# Disordered Systems and Neural Networks            0.166667  0.111111
# Distributed, Parallel, and Cluster Computing      0.628571  0.550000
# Formal Languages and Automata Theory              0.750000  0.500000
# Human-Computer Interaction                        0.727273  0.500000
# Information Retrieval                             0.718750  0.575000
# Information Theory (Computer Science)             0.916923  0.884273
# Information Theory (Mathematics)                  0.975510  0.709199
# Logic                                             0.800000  0.444444
# Logic in Computer Science                         0.846154  0.687500
# Machine Learning (Computer Science)               0.651934  0.808219
# Machine Learning (Statistics)                     0.700000  0.223404
# Mathematical Software                             0.333333  0.142857
# Methodology                                       0.000000  0.000000
# Multiagent Systems                                0.400000  0.285714
# Multimedia                                        0.857143  0.400000
# Networking and Internet Architecture              0.666667  0.555556
# Neural and Evolutionary Computing                 0.653846  0.548387
# Neurons and Cognition                             0.625000  0.625000
# Number Theory                                     0.600000  0.750000
# Numerical Analysis (Computer Science)             0.550000  0.550000
# Numerical Analysis (Mathematics)                  0.600000  0.300000
# Optimization and Control                          0.500000  0.698113
# Performance                                       0.538462  0.466667
# Physics and Society                               0.906250  0.475410
# Probability                                       0.500000  0.400000
# Programming Languages                             0.774194  0.888889
# Quantitative Methods                              1.000000  0.333333
# Quantum Physics                                   0.937500  0.833333
# Robotics                                          0.666667  0.375000
# Social and Information Networks                   0.833333  0.633803
# Software Engineering                              0.571429  0.600000
# Statistical Mechanics                             0.333333  0.214286
# Statistics Theory (Mathematics)                   0.285714  0.200000
# Statistics Theory (Statistics)                    0.000000  0.000000
# Symbolic Computation                              0.600000  0.272727
# Systems and Control (Computer Science)            0.750000  0.477273
# micro avg                                         0.724237  0.627014
# macro avg                                         0.609922  0.497037
# weighted avg                                      0.740160  0.627014
# samples avg                                       0.726750  0.659162
#
#                                                  f1-score  support
# Adaptation and Self-Organizing Systems           0.222222      8.0
# Applications                                     0.090909     14.0
# Artificial Intelligence                          0.594059    111.0
# Combinatorics                                    0.639344     60.0
# Computation and Language                         0.811881     51.0
# Computational Complexity                         0.543689     44.0
# Computational Engineering, Finance, and Science  0.352941     24.0
# Computational Geometry                           0.590909     22.0
# Computational Linguistics                        0.740741     15.0
# Computer Science and Game Theory                 0.740741     29.0
# Computer Vision and Pattern Recognition          0.843373     43.0
# Computers and Society                            0.527778     39.0
# Cryptography and Security                        0.865979     49.0
# Data Analysis, Statistics and Probability        0.117647      9.0
# Data Structures and Algorithms                   0.559524     78.0
# Databases                                        0.536585     24.0
# Digital Libraries                                0.666667     13.0
# Discrete Mathematics                             0.540541     68.0
# Disordered Systems and Neural Networks           0.133333      9.0
# Distributed, Parallel, and Cluster Computing     0.586667     40.0
# Formal Languages and Automata Theory             0.600000     18.0
# Human-Computer Interaction                       0.592593     16.0
# Information Retrieval                            0.638889     40.0
# Information Theory (Computer Science)            0.900302    337.0
# Information Theory (Mathematics)                 0.821306    337.0
# Logic                                            0.571429      9.0
# Logic in Computer Science                        0.758621     64.0
# Machine Learning (Computer Science)              0.721713    146.0
# Machine Learning (Statistics)                    0.338710     94.0
# Mathematical Software                            0.200000      7.0
# Methodology                                      0.000000      3.0
# Multiagent Systems                               0.333333     14.0
# Multimedia                                       0.545455     15.0
# Networking and Internet Architecture             0.606061     54.0
# Neural and Evolutionary Computing                0.596491     31.0
# Neurons and Cognition                            0.625000      8.0
# Number Theory                                    0.666667      4.0
# Numerical Analysis (Computer Science)            0.550000     20.0
# Numerical Analysis (Mathematics)                 0.400000     20.0
# Optimization and Control                         0.582677     53.0
# Performance                                      0.500000     15.0
# Physics and Society                              0.623656     61.0
# Probability                                      0.444444     20.0
# Programming Languages                            0.827586     27.0
# Quantitative Methods                             0.500000      6.0
# Quantum Physics                                  0.882353     36.0
# Robotics                                         0.480000     16.0
# Social and Information Networks                  0.720000     71.0
# Software Engineering                             0.585366     20.0
# Statistical Mechanics                            0.260870     14.0
# Statistics Theory (Mathematics)                  0.235294     20.0
# Statistics Theory (Statistics)                   0.000000     20.0
# Symbolic Computation                             0.375000     11.0
# Systems and Control (Computer Science)           0.583333     44.0
# micro avg                                        0.672128   2421.0
# macro avg                                        0.532827   2421.0
# weighted avg                                     0.666597   2421.0
# samples avg                                      0.682455   2421.0

# %%
result = {
    "model": "qwen2.5:7b",
    "dataset": "AAPD",
    "prompt_strategy": "topk_5_examples_label_descriptions",
    "test_f1_micro": f1_score(llm_y_test, llm_y_test_pred, average="micro", zero_division=0),
    "test_f1_macro": f1_score(llm_y_test, llm_y_test_pred, average="macro", zero_division=0),
    "avg_predicted_labels": np.mean([len(row["predicted_labels"]) for row in ok_rows]),
    "avg_inference_time_sec": np.mean([row["total_sample_runtime_seconds"] for row in ok_rows]),
    "inference_per_sample_ms": np.mean([row["total_sample_runtime_seconds"] for row in ok_rows]) * 1000,
    "total_wall_time_min": 43.89,
    "n_error_rows": len(error_rows)}

result_df = pd.DataFrame([result])
result_df.to_csv(f"{OUTPUT_DIR}/AAPD_Qwen_Ollama_topk_test_results_summary.csv", index=False)
result
# Out:
# {'model': 'qwen2.5:7b',
#  'dataset': 'AAPD',
#  'prompt_strategy': 'topk_5_examples_label_descriptions',
#  'test_f1_micro': 0.6721275182643347,
#  'test_f1_macro': 0.5328273735105804,
#  'avg_predicted_labels': np.float64(2.096),
#  'avg_inference_time_sec': np.float64(2.6271349494457246),
#  'inference_per_sample_ms': np.float64(2627.1349494457245),
#  'total_wall_time_min': 43.89,
#  'n_error_rows': 0}
